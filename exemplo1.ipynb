# %%
listas = ["maçã", "banana", "laranja"] # mutaveis, permitem elementos duplicados, possuem ordem
tuplas = ("maçã", "banana", "laranja") # imutaveis, permitem elementos duplicados, possuem ordem
conjuntos = {"maçã", "banana", "laranja"} # mutaveis, não permitem elementos duplicados, não possuem ordem
dicionarios = {"fruta1": "maçã", "fruta2": "banana", "fruta3": "laranja"} # mutaveis, não permitem chaves duplicadas, possuem ordem

# %%
# exemplo de loops
idade = 20


if idade >= 18:
  print(f"você é maior de idade {idade}")


if idade >= 18:
  print(f"você é maior de idade {idade}")
else:  
  print(f"você é menor de idade {idade}")


if idade >= 18:
  print(f"você é maior de idade {idade}")
elif idade >= 65:
  print(f"você já é idoso {idade}")
else:  
  print(f"você é menor de idade {idade}")

# %%
frutas = ["maçã", "banana", "laranja"]
for fruta in frutas:
  print(fruta)


primeiro_elemento = frutas[0]
print(primeiro_elemento)


frutas.append("uva")
print(frutas)


frutas.remove("banana")
print(frutas)


frutas_set = set(frutas)
print(frutas_set)


frutas_list = list(frutas_set)
print(frutas_list)

# %%
frutas = {"maçã", "banana", "laranja", "banana"}
for fruta in frutas:
  print(fruta)


if "banana" in frutas:
  print("existe banana")


frutas.add("uva")
print(frutas)


frutas.remove("banana")
print(frutas)

# %%
itens_inventario = [
  {"nome": "maçã", "quantidade": 10},
  {"nome": "banana", "quantidade": 5},
  {"nome": "laranja", "quantidade": 8}
]

for item in itens_inventario:
  print(f"{item['nome']}: {item['quantidade']} unidades")

for item in itens_inventario:
  if item["nome"] == "banana":
    print(f"quantidade de bananas: {item['quantidade']} unidades")

itens_inventario.append(
  {"nome": "uva", "quantidade": 12}
)
print(len(itens_inventario))
print(itens_inventario[-1])
print(itens_inventario[-1]["nome"])
print(itens_inventario[-1]["quantidade"])

itens_inventario.remove(itens_inventario[1])
print(itens_inventario)

# %%
for i in range(5):
  print(i)

for i in range(2, 9, 2):
  print(i)

for num in range(10):
  if num % 2 == 0:
    print(f"{num} é par")
  else:
    print(f"{num} é ímpar")

# %%
contador = 0
while contador < 10:
  print(f"contador: {contador}")
  # print(f"contador: {5 - contador}")
  
  # if contador == 5:
  #   print("contador chegou a 5, saindo do loop")
  # if contador == 5:
  #   print("contador chegou a 5, saindo do loop")
  #   break
  contador += 1

# %%
estante = ["biblia", "dante", "shakespeare", "tolstoy", "cervantes"]
for livro in estante:
  print(livro)

if "biblia" in estante:
  print("existe a bíblia na estante")

if "biblia" in estante or "dante" in estante:
  print("existe a bíblia na estante")
  
if "hobbit" in estante and "dante" in estante:
  print("existe o hobbit e dante na estante")

if "hobbit" not in estante:
  print("não existe o hobbit na estante")

# %%
try:
  numero = int(input("Digite um número: "))
  resultado = 10 / numero
except ValueError:
  print("Erro: Você precisa digitar um número inteiro!")
except ZeroDivisionError:
  print("Erro: Não existe divisão por zero!")

# %%
with open("arquivo.txt", "w") as arquivo:
  arquivo.write("Olá, mundo!\n")
  arquivo.write("Este é um exemplo de escrita em um arquivo.\n")

with open("arquivo.txt", "a") as arquivo:
  arquivo.write("Adicionando mais uma linha ao arquivo.\n")

with open("arquivo.txt", "r") as arquivo:
  conteudo = arquivo.read()
  print(conteudo)

# %%
import os

caminho_arquivo = "arquivo.txt"
caminho_teste = os.path.exists(caminho_arquivo)
if caminho_teste:
  print(f"O arquivo {caminho_arquivo} existe.")
  print(type(caminho_teste))
else:
  print(f"O arquivo {caminho_arquivo} não existe.")

# %%
def calculadora():
  while True:
    print("\n--- CALCULADORA ---")
    print("1. Soma (+)")
    print("2. Subtração (-)")
    print("3. Multiplicação (*)")
    print("4. Divisão (/)")
    print("5. Sair")

    opcao = input("Escolha uma opção (1-5): ")

    if opcao == '5':
      print("Encerrando a calculadora... Até logo!")
      break

    if opcao in ['1', '2', '3', '4']:
      try:
        # Usamos float para permitir números decimais
        num1 = float(input("Digite o primeiro número: "))
        num2 = float(input("Digite o segundo número: "))

        if opcao == '1':
          print(f"Resultado: {num1} + {num2} = {num1 + num2}")
        elif opcao == '2':
          print(f"Resultado: {num1} - {num2} = {num1 - num2}")
        elif opcao == '3':
          print(f"Resultado: {num1} * {num2} = {num1 * num2}")
        elif opcao == '4':
          if num2 == 0:
            print("Erro: Não é possível dividir por zero!")
          else:
            print(f"Resultado: {num1} / {num2} = {num1 / num2}")
      
      except ValueError:
        print("Erro: Por favor, digite apenas números válidos.")
    else:
      print("Opção inválida! Tente novamente.")

# Chama a função para rodar o programa
calculadora()
